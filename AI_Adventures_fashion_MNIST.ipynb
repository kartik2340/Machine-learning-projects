# %% [markdown]
# <a href="https://colab.research.google.com/github/kartik2340/Machine-learning-projects/blob/main/AI_Adventures_fashion_MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt 
print(tf.__version__)
# Out:
# 2.8.2

# %%
fashion_mnist= keras.datasets.fashion_mnist
(train_images,train_labeles),(test_image, test_labels)= fashion_mnist.load_data()

# %%
class_names = ['T-shirts/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']

# %%
 train_images.shape
# Out:
# (60000, 28, 28)

# %%
 len(train_labeles)
# Out:
# 60000

# %%
len(train_images)
# Out:
# 60000

# %%
plt.figure()
plt.imshow(test_image[60])
plt.colorbar()
plt.gca().grid(False)

# %%
plt.figure()
plt.imshow(train_images[45])
plt.colorbar()
plt.gca().grid(False)

# %%
plt.figure()
plt.imshow(train_images[1])
plt.colorbar()
plt.gca().grid(False)

# %%
plt.figure()
plt.imshow(train_images[40])
plt.colorbar()
plt.gca().grid(False)

# %%
  train_images = train_images/255.0
  test_image = test_image/255.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(12,12))
for i in range(30):
  plt.subplot(5,6,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid('off')
  plt.imshow(train_images[i], cmap=plt.cm.binary)
  plt.xlabel(class_names[train_labeles[i]])

# %%
  model = tf.keras.Sequential([
       tf.keras.layers.Flatten(input_shape=(28,28)),
       tf.keras.layers.Dense(130,activation="relu"),
       tf.keras.layers.Dense(12),
  ])
  model.compile(optimizer="adam",
                loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics = ["accuracy"]
                )
  model.fit(train_images,train_labeles,epochs=20)
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5048 - accuracy: 0.8229
# Epoch 2/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3793 - accuracy: 0.8636
# Epoch 3/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3375 - accuracy: 0.8765
# Epoch 4/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3144 - accuracy: 0.8848
# Epoch 5/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2971 - accuracy: 0.8906
# Epoch 6/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2818 - accuracy: 0.8944
# Epoch 7/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2699 - accuracy: 0.8997
# Epoch 8/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2575 - accuracy: 0.9047
# Epoch 9/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2473 - accuracy: 0.9084
# Epoch 10/20
# ...

# %%
model.predict(test_image)[60]
test_labels[60]
# Out:
# 7
